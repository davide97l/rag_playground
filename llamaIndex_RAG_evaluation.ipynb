# %% [markdown]
# # Pipeline for evaluating RAG dataset

# %%
from dotenv import load_dotenv
load_dotenv()

import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Response Evaluation
#
# Measures how good are the responses of the model given the context an ground truth answer. Does the response match the retrieved context? Does it also match the query? Does it match the reference answer or guidelines?
#
# These evaluation modules are in the following forms:
#
# - Correctness: Whether the generated answer matches that of the reference answer given the query (requires labels).
# - Semantic Similarity Whether the predicted answer is semantically similar to the reference answer (requires labels).
# - Faithfulness: Evaluates if the answer is faithful to the retrieved contexts (in other words, whether if there's hallucination).
# - Context Relevancy: Whether retrieved context is relevant to the query.
# - Answer Relevancy: Whether the generated answer is relevant to the query.
# - Guideline Adherence: Whether the predicted answer adheres to specific guidelines.

# %% [markdown]
# ## Load predefined dataset
#
# let's start with evaluating existing datasets. More datasets can be downloaded from: https://llamahub.ai/?tab=llama_datasets

# %%
from llama_index.core.llama_dataset import download_llama_dataset

# download and install dependencies
rag_dataset, documents = download_llama_dataset(
    "PaulGrahamEssayDataset", "./data/paul_graham"
)

# %%
rag_dataset.to_pandas()
# Out:
#                                                 query  \
# 0   In the essay, the author mentions his early ex...
# 1   The author switched his major from philosophy ...
# 2   In the essay, the author discusses his initial...
# 3   The author mentions his shift of interest towa...
# 4   In the essay, the author mentions his interest...
# 5   The author discusses his decision to write a b...
# 6   In the essay, the author mentions a quick deci...
# 7   The author describes the atmosphere and practi...
# 8   In the essay, the author discusses his experie...
# 9   The author shares his work experience at a com...
# 10  In the essay, the author discusses his experie...
# 11  The author discusses the concept of a "signatu...
# 12  In the context of the essay, what was the auth...
# 13  According to the author's experience, why was ...
# 14  In the essay by Paul Graham, what was the init...
# 15  Describe the pivotal moment in the essay when ...
# 16  In the context of the essay, describe the thre...
# 17  The author mentions that their pricing strateg...
# 18  In the context of the essay, how did the autho...
# 19  Discuss the author's perspective on the import...
# 20  In the essay, the author mentions a transition...
# 21  The author experimented with a new kind of sti...
# 22  In the essay, the author discusses an idea for...
# 23  The author mentions a new dialect of Lisp that...
# 24  In the context of Paul Graham's essay, explain...
# 25  Analyze the shift in publishing essays from th...
# 26  In the essay by Paul Graham, he discusses his ...
# 27  Paul Graham mentions a strategy he used for wr...
# 28  In the essay by Paul Graham, describe the uniq...
# 29  Discuss the inception and initial implementati...
# 30  In the Summer Founders Program mentioned in th...
# 31  Discuss the role of Hacker News (HN) in the co...
# 32  In the essay, Paul Graham mentions a significa...
# 33  Discuss the transition of leadership at Y Comb...
# 34  In the context of the essay, why did the autho...
# 35  Discuss the significance of Lisp as a programm...
# 36  In the essay, the author discusses the develop...
# 37  The author mentions a significant life change ...
# 38  In the essay by Paul Graham, he discusses his ...
# 39  The author mentions several notes at the end o...
# 40  In the essay, Paul Graham discusses the concep...
# 41  Paul Graham uses the example of advanced alien...
# 42  In the essay by Paul Graham, he discusses the ...
# 43  Paul Graham mentions his experience of leaving...
#
#                                    reference_contexts  \
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 2   [I couldn't have put this into words when I wa...
# 3   [I couldn't have put this into words when I wa...
# 4   [So I looked around to see what I could salvag...
# 5   [So I looked around to see what I could salvag...
# 6   [I didn't want to drop out of grad school, but...
# 7   [I didn't want to drop out of grad school, but...
# 8   [We actually had one of those little stoves, f...
# 9   [We actually had one of those little stoves, f...
# 10  [But Interleaf still had a few years to live y...
# 11  [But Interleaf still had a few years to live y...
# 12  [Painting students were supposed to express th...
# 13  [Painting students were supposed to express th...
# 14  [Meanwhile I'd been hearing more and more abou...
# 15  [Meanwhile I'd been hearing more and more abou...
# 16  [In return for that and doing the initial lega...
# 17  [In return for that and doing the initial lega...
# 18  [Which meant being easy to use and inexpensive...
# 19  [Which meant being easy to use and inexpensive...
# 20  [But it didn't feel very valuable to me; I had...
# 21  [But it didn't feel very valuable to me; I had...
# 22  [It was as weird as it sounds. I resumed all m...
# 23  [It was as weird as it sounds. I resumed all m...
# 24  [Much to my surprise, the time I spent working...
# 25  [Much to my surprise, the time I spent working...
# 26  [It's not that unprestigious types of work are...
# 27  [It's not that unprestigious types of work are...
# 28  [As Jessica and I were walking home from dinne...
# 29  [As Jessica and I were walking home from dinne...
# 30  [[15] We got 225 applications for the Summer F...
# 31  [[15] We got 225 applications for the Summer F...
# 32  [When I was dealing with some urgent problem d...
# 33  [When I was dealing with some urgent problem d...
# 34  [Up till that point YC had been controlled by ...
# 35  [Up till that point YC had been controlled by ...
# 36  [It was missing a lot of things you'd want in ...
# 37  [It was missing a lot of things you'd want in ...
# 38  [Now that I could write essays again, I wrote ...
# 39  [Now that I could write essays again, I wrote ...
# 40  [People who see the responses to essays I writ...
# 41  [People who see the responses to essays I writ...
# 42  [[18] The worst thing about leaving YC was not...
# 43  [[18] The worst thing about leaving YC was not...
#
#                                      reference_answer reference_answer_by  \
# 0   The first computer the author used for program...          ai (gpt-4)
# 1   The two specific influences that led the autho...          ai (gpt-4)
# 2   The two main influences that initially drew th...          ai (gpt-4)
# 3   The author shifted his interest towards Lisp a...          ai (gpt-4)
# 4   The author in the essay is Paul Graham, who wa...          ai (gpt-4)
# 5   The author decided to write a book on Lisp hac...          ai (gpt-4)
# 6   The author decided to attempt writing his diss...          ai (gpt-4)
# 7   According to the author's account, the student...          ai (gpt-4)
# 8   In the essay, the author explains that paintin...          ai (gpt-4)
# 9   Interleaf, the company where the author worked...          ai (gpt-4)
# 10  The author was hired by Interleaf as a Lisp ha...          ai (gpt-4)
# 11  A "signature style" is a unique and identifiab...          ai (gpt-4)
# 12  The author initially perceived the World Wide ...          ai (gpt-4)
# 13  The author's idea of starting a company to put...          ai (gpt-4)
# 14  The initial idea for a startup by Paul Graham ...          ai (gpt-4)
# 15  The pivotal moment in the essay when the autho...          ai (gpt-4)
# 16  The three main parts of the software developed...          ai (gpt-4)
# 17  The author and his team priced their ecommerce...          ai (gpt-4)
# 18  The author's lack of business knowledge inadve...          ai (gpt-4)
# 19  The author believes that the growth rate is th...          ai (gpt-4)
# 20  In the essay, the author describes a significa...          ai (gpt-4)
# 21  The author's new approach to still life painti...          ai (gpt-4)
# 22  In the essay, the author discusses the idea of...          ai (gpt-4)
# 23  The author mentions that Lisp hackers often dr...          ai (gpt-4)
# 24  In Paul Graham's essay, his work on the new di...          ai (gpt-4)
# 25  In the essay, Paul Graham describes a signific...          ai (gpt-4)
# 26  In Paul Graham's essay, several key events and...          ai (gpt-4)
# 27  Paul Graham found that giving talks was an eff...          ai (gpt-4)
# 28  Y Combinator, as described in Paul Graham's es...          ai (gpt-4)
# 29  In Paul Graham's essay, the inception of the S...          ai (gpt-4)
# 30  The deal for startups in the Summer Founders P...          ai (gpt-4)
# 31  Hacker News (HN) was initially created as a ne...          ai (gpt-4)
# 32  In the essay, Robert Morris advised Paul Graha...          ai (gpt-4)
# 33  The transition of leadership at Y Combinator w...          ai (gpt-4)
# 34  The author decided to step away from YC to hel...          ai (gpt-4)
# 35  In the essay, the author describes Lisp as a p...          ai (gpt-4)
# 36  The author developed a new programming languag...          ai (gpt-4)
# 37  The significant life change that occurred duri...          ai (gpt-4)
# 38  In Paul Graham's essay, he reflects on his own...          ai (gpt-4)
# 39  Without the full context of the essay, it's di...          ai (gpt-4)
# 40  Yes, Paul Graham discusses the concept of cust...          ai (gpt-4)
# 41  Paul Graham uses the analogy of advanced alien...          ai (gpt-4)
# 42  In the essay, Paul Graham uses the concept of ...          ai (gpt-4)
# 43  Paul Graham describes his experience of leavin...          ai (gpt-4)
#
#       query_by
# 0   ai (gpt-4)
# 1   ai (gpt-4)
# 2   ai (gpt-4)
# 3   ai (gpt-4)
# 4   ai (gpt-4)
# 5   ai (gpt-4)
# 6   ai (gpt-4)
# 7   ai (gpt-4)
# 8   ai (gpt-4)
# 9   ai (gpt-4)
# 10  ai (gpt-4)
# 11  ai (gpt-4)
# 12  ai (gpt-4)
# 13  ai (gpt-4)
# 14  ai (gpt-4)
# 15  ai (gpt-4)
# 16  ai (gpt-4)
# 17  ai (gpt-4)
# 18  ai (gpt-4)
# 19  ai (gpt-4)
# 20  ai (gpt-4)
# 21  ai (gpt-4)
# 22  ai (gpt-4)
# 23  ai (gpt-4)
# 24  ai (gpt-4)
# 25  ai (gpt-4)
# 26  ai (gpt-4)
# 27  ai (gpt-4)
# 28  ai (gpt-4)
# 29  ai (gpt-4)
# 30  ai (gpt-4)
# 31  ai (gpt-4)
# 32  ai (gpt-4)
# 33  ai (gpt-4)
# 34  ai (gpt-4)
# 35  ai (gpt-4)
# 36  ai (gpt-4)
# 37  ai (gpt-4)
# 38  ai (gpt-4)
# 39  ai (gpt-4)
# 40  ai (gpt-4)
# 41  ai (gpt-4)
# 42  ai (gpt-4)
# 43  ai (gpt-4)

# %%
from llama_index.core import VectorStoreIndex

# a basic RAG pipeline, uses service context defaults
index = VectorStoreIndex.from_documents(documents=documents)
query_engine = index.as_query_engine()

# %% [markdown]
# ## Evaluate with RagEvaluatorPack

# %%
from llama_index.core.llama_pack import download_llama_pack

RagEvaluatorPack = download_llama_pack("RagEvaluatorPack", "./pack")

rag_evaluator = RagEvaluatorPack(
    query_engine=query_engine,  # built with the same source Documents as the rag_dataset
    rag_dataset=rag_dataset,
)
benchmark_df = rag_evaluator.run()
# Out:
# 2it [00:41, 20.89s/it]
# 2it [00:21, 10.70s/it]
# 2it [00:30, 15.46s/it]
# 2it [00:20, 10.06s/it]
# 1it [00:19, 19.03s/it]/Users/davideliu/miniconda3/envs/llm_testing/lib/python3.10/socket.py:518: RuntimeWarning: coroutine 'CorrectnessEvaluator.aevaluate' was never awaited
#   return _intenum_converter(super().family, AddressFamily)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2it [00:32, 16.50s/it]
# 2it [00:18,  9.04s/it]
# 2it [00:23, 11.52s/it]
# 2it [00:24, 12.27s/it]
# 2it [00:20, 10.41s/it]
# 2it [00:32, 16.00s/it]
# 2it [00:30, 15.14s/it]
# 2it [00:21, 10.67s/it]
# 2it [00:32, 16.07s/it]
# 2it [00:29, 14.53s/it]
# 2it [00:23, 11.88s/it]
# 2it [00:23, 11.61s/it]
# 2it [00:30, 15.45s/it]
# 2it [00:37, 18.73s/it]
# 2it [00:19,  9.59s/it]
# 2it [00:41, 20.87s/it]
# 2it [00:28, 14.04s/it]
# 2it [00:27, 13.95s/it]

# %%
benchmark_df.head()
# Out:
# rag                            base_rag
# metrics
# mean_correctness_score         4.011364
# mean_relevancy_score           0.772727
# mean_faithfulness_score        1.000000
# mean_context_similarity_score  0.926472

# %% [markdown]
# ## Low level evaluation

# %%
# generate prediction dataset
prediction_dataset = await rag_dataset.amake_predictions_with(
    predictor=query_engine, show_progress=True
)

# %%
prediction_dataset.to_pandas()[:10]
# Out:
#                                             response  \
# 0  The author's first experience with programming...
# 1  The author was influenced to develop an intere...
# 2  The author mentions that two main influences t...
# 3  The author shifted his interest towards Lisp b...
# 4  The author of the essay tries to reconcile his...
# 5  The author decided to write a book on Lisp hac...
# 6  The author made a quick decision to claim that...
# 7  The students and faculty at the Accademia di B...
# 8  The process of painting a still life differs f...
# 9  Interleaf had added a scripting language to th...
#
#                                             contexts
# 0  [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1  [All that seemed left for philosophy were edge...
# 2  [All that seemed left for philosophy were edge...
# 3  [Its brokenness did, as so often happens, gene...
# 4  [If he even knew about the strange classes I w...
# 5  [Its brokenness did, as so often happens, gene...
# 6  [If he even knew about the strange classes I w...
# 7  [The students and faculty in the painting depa...
# 8  [The students and faculty in the painting depa...
# 9  [I wanted to go back to RISD, but I was now br...

# %%
import tqdm
from llama_index.llms.openai import OpenAI
from llama_index.core.evaluation import (
    CorrectnessEvaluator,
    EvaluationResult,
    FaithfulnessEvaluator,
    RelevancyEvaluator,
    SemanticSimilarityEvaluator,
)

judges = {}
judges["correctness"] = CorrectnessEvaluator(
    llm=OpenAI(temperature=0, model="gpt-4-1106-preview")
)

for example, prediction in tqdm.tqdm(
    zip(rag_dataset.examples, prediction_dataset.predictions)
):
    correctness_result = judges["correctness"].evaluate(
        query=example.query,
        response=prediction.response,
        reference=example.reference_answer,
    )
# Out:
# 44it [04:31,  6.17s/it]

# %%
correctness_result
# Out:
# EvaluationResult(query='Paul Graham mentions his experience of leaving YC and no longer working with Jessica. How does he describe this experience and what does it reveal about his personal and professional relationship with Jessica?', contexts=None, response='Paul Graham describes his experience of leaving YC and no longer working with Jessica as the worst thing about leaving YC. This reveals that his personal and professional relationship with Jessica was significant and valued by him. Despite the challenges and stresses associated with his work, the absence of working with Jessica stood out as a particularly negative aspect of his departure from Y Combinator.', passing=True, feedback='The generated answer is relevant and correct in capturing the essence of Paul Graham\'s sentiment about leaving YC and no longer working with Jessica. It correctly identifies that the relationship was significant and valued. However, it does not use the specific metaphor of "pulling up a deeply rooted tree," which was in the reference answer and might provide a more vivid description of the depth of their relationship. Despite this, the generated answer still conveys the main point effectively.', score=4.0, pairwise_source=None, invalid_result=False, invalid_reason=None)

# %% [markdown]
# ## Generate custom RAG dataset for evaluation from custom documents
#
# Will be useful later when we will have to work with our own dataset

# %%
# generate questions against chunks
from llama_index.core.llama_dataset.generator import RagDatasetGenerator
from llama_index.llms.openai import OpenAI
from llama_index.core import ServiceContext
from llama_index.core import SimpleDirectoryReader

# set context for llm provider
gpt_4_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-4", temperature=0.3)
)

documents = SimpleDirectoryReader("./data/paul_graham").load_data()

# instantiate a DatasetGenerator
dataset_generator = RagDatasetGenerator.from_documents(
    documents,
    service_context=gpt_4_context,
    num_questions_per_chunk=2,  # set the number of questions per nodes
    show_progress=True,
)
# Out:
# /var/folders/_3/82nb1p1n24xcwn459tvc3kp40000gn/T/ipykernel_58748/4188557123.py:8: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   gpt_4_context = ServiceContext.from_defaults(
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
rag_dataset = dataset_generator.generate_dataset_from_nodes()

# %%
rag_dataset.to_pandas()
# Out:
#                                                  query  \
# 0    Describe the author's initial experience with ...
# 1    How did the author's approach to programming c...
# 2    "Describe the author's initial interest in phi...
# 3    "Discuss the two specific influences that spar...
# 4    "What were the two specific influences that le...
# ..                                                 ...
# 137  "Explain how Paul Graham connects the evolutio...
# 138  In Paul Graham's essay, he uses the analogy of...
# 139  Paul Graham describes his experience of leavin...
# 140  In Paul Graham's metaphor, what does the "deep...
# 141  Based on Paul Graham's discussion on the conce...
#
#                                     reference_contexts  \
# 0    [{\n    "examples": [\n        {\n            ...
# 1    [{\n    "examples": [\n        {\n            ...
# 2    [In college I was going to study philosophy, w...
# 3    [In college I was going to study philosophy, w...
# 4    [You had to type programs on punch cards, then...
# ..                                                 ...
# 137  [Customary VC practice had once, like the cust...
# 138  [Presumably aliens need numbers and errors and...
# 139  [Presumably aliens need numbers and errors and...
# 140  [We'd been working on YC almost the whole time...
# 141  [We'd been working on YC almost the whole time...
#
#                                       reference_answer reference_answer_by  \
# 0    The author's initial experience with programmi...          ai (gpt-4)
# 1    With the advent of microcomputers, the author'...          ai (gpt-4)
# 2    The author initially found philosophy appealin...          ai (gpt-4)
# 3    The author's interest in AI was sparked by two...          ai (gpt-4)
# 4    The two specific influences that led the autho...          ai (gpt-4)
# ..                                                 ...                 ...
# 137  Paul Graham draws a parallel between the evolu...          ai (gpt-4)
# 138  Paul Graham uses the Pythagorean theorem and L...          ai (gpt-4)
# 139  The metaphor of "pulling up a deeply rooted tr...          ai (gpt-4)
# 140  In Paul Graham's metaphor, the "deeply rooted ...          ai (gpt-4)
# 141  Paul Graham suggests that any sufficiently adv...          ai (gpt-4)
#
#        query_by
# 0    ai (gpt-4)
# 1    ai (gpt-4)
# 2    ai (gpt-4)
# 3    ai (gpt-4)
# 4    ai (gpt-4)
# ..          ...
# 137  ai (gpt-4)
# 138  ai (gpt-4)
# 139  ai (gpt-4)
# 140  ai (gpt-4)
# 141  ai (gpt-4)
#
# [142 rows x 5 columns]

# %% [markdown]
# ## Evaluate retriever
#
# Measures the capability of the retriever to retrieve the right sources. Are the retrieved sources relevant to the query?
#
# The core retrieval evaluation steps revolve around the following:
# - Dataset generation: Given an unstructured text corpus, synthetically generate (question, context) pairs.
# - Retrieval Evaluation: Given a retriever and a set of questions, evaluate retrieved results using ranking metrics.
#
# Metrics used:
# - mrr
# - hit_rate

# %%
from llama_index.core import Document
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.extractors import TitleExtractor
from llama_index.core.ingestion import IngestionPipeline, IngestionCache

# create the pipeline with transformations
pipeline = IngestionPipeline(
    transformations=[
        SentenceSplitter(chunk_size=512, chunk_overlap=25),
    ]
)

# run the pipeline
nodes = pipeline.run(documents=documents)
index_nodes = VectorStoreIndex(nodes)

# %%
len(nodes)
# Out:
# 38

# %%
from llama_index.core.evaluation import (
    generate_question_context_pairs,
    EmbeddingQAFinetuneDataset,
)
from llama_index.llms.openai import OpenAI

llm=OpenAI(temperature=0, model="gpt-4")
qa_dataset = generate_question_context_pairs(
    nodes, llm=llm, num_questions_per_chunk=2
)
qa_dataset.save_json("data/paul_graham/retriever_eval_dataset.json")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [02:49<00:00,  4.47s/it]

# %%
# qa_dataset = EmbeddingQAFinetuneDataset.from_json("data/paul_graham/retriever_eval_dataset.json")

# %%
from llama_index.core.evaluation import RetrieverEvaluator

metrics = ["mrr", "hit_rate"]

retriever = index_nodes.as_retriever(similarity_top_k=2)
retriever_evaluator = RetrieverEvaluator.from_metric_names(
    metrics, retriever=retriever
)

# %%
sample_id, sample_query = list(qa_dataset.queries.items())[0]
sample_expected = qa_dataset.relevant_docs[sample_id]

eval_result = retriever_evaluator.evaluate(sample_query, sample_expected)
print(eval_result)
# Out:
# Query: "Describe the author's early experiences with programming on the IBM 1401. What were some of the challenges he faced and how did these experiences shape his understanding of programming?"
# Metrics: {'mrr': 1.0, 'hit_rate': 1.0}

# %%
eval_results = await retriever_evaluator.aevaluate_dataset(qa_dataset)

# %%
import pandas as pd


def display_results(name, eval_results):
    """Display results from evaluate."""

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    hit_rate = full_df["hit_rate"].mean()
    mrr = full_df["mrr"].mean()
    columns = {"retrievers": [name], "hit_rate": [hit_rate], "mrr": [mrr]}

    metric_df = pd.DataFrame(columns)

    return metric_df

# %%
display_results("top-2 eval", eval_results)
# Out:
#    retrievers  hit_rate       mrr
# 0  top-2 eval  0.842105  0.769737

# %%
from llama_index.core.response.notebook_utils import display_source_node

retrieved_nodes = retriever.retrieve("In the essay, the author mentions his early experiences with programming. Describe the first computer he used for programming, the language he used, and the challenges he faced.")
for node in retrieved_nodes:
    display_source_node(node, source_length=1000)
# Out:
# **Node ID:** db667069-f991-4332-a110-fe38b99b0697<br>**Similarity:** 0.8743050242610546<br>**Text:** What I Worked On
#
# February 2021
#
# Before college the two main things I worked on, outside of school, were writing and programming. I didn't write essays. I wrote what beginning writers were supposed to write then, and probably still are: short stories. My stories were awful. They had hardly any plot, just characters with strong feelings, which I imagined made them deep.
#
# The first programs I tried writing were on the IBM 1401 that our school district used for what was then called "data processing." This was in 9th grade, so I was 13 or 14. The school district's 1401 happened to be in the basement of our junior high school, and my friend Rich Draves and I got permission to use it. It was like a mini Bond villain's lair down there, with all these alien-looking machines â CPU, disk drives, printer, card reader â sitting up on a raised floor under bright fluorescent lights.
#
# The language we used was an early version of Fortran. You had to type programs on punch cards, then stack them...<br>
# **Node ID:** 26e8864e-e1e1-4f48-8a20-2561a79c7c3f<br>**Similarity:** 0.8739117193294521<br>**Text:** With microcomputers, everything changed. Now you could have a computer sitting right in front of you, on a desk, that could respond to your keystrokes as it was running instead of just churning through a stack of punch cards and then stopping. [1]
#
# The first of my friends to get a microcomputer built it himself. It was sold as a kit by Heathkit. I remember vividly how impressed and envious I felt watching him sitting in front of it, typing programs right into the computer.
#
# Computers were expensive in those days and it took me years of nagging before I convinced my father to buy one, a TRS-80, in about 1980. The gold standard then was the Apple II, but a TRS-80 was good enough. This was when I really started programming. I wrote simple games, a program to predict how high my model rockets would fly, and a word processor that my father used to write at least one book. There was only room in memory for about 2 pages of text, so he'd write 2 pages at a time and then print them out, but...<br>

# %% [markdown]
# ## References
#
# - https://docs.llamaindex.ai/en/latest/module_guides/evaluating/evaluating_with_llamadatasets/#using-a-labelledragdataset
# - https://www.llamaindex.ai/blog/introducing-llama-datasets-aadb9994ad9e
# - https://docs.llamaindex.ai/en/stable/module_guides/evaluating/evaluating_with_llamadatasets/#building-a-labelledragdataset
# - https://docs.llamaindex.ai/en/stable/examples/evaluation/retrieval/retriever_eval/
