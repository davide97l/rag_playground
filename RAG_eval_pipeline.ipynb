# %%
from llama_index.core import Document
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.extractors import TitleExtractor
from llama_index.core.ingestion import IngestionPipeline, IngestionCache
from llama_index.core.llama_dataset.generator import RagDatasetGenerator
from llama_index.llms.openai import OpenAI
from llama_index.core import ServiceContext
from llama_index.core import SimpleDirectoryReader
from llama_index.core import VectorStoreIndex
from llama_index.core import get_response_synthesizer
from llama_index.core.indices.vector_store.retrievers import VectorIndexRetriever
from llama_index.core.query_engine.retriever_query_engine import (
    RetrieverQueryEngine,
)
from llama_index.core.llama_dataset import LabelledRagDataset
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import StorageContext, load_index_from_storage
from llama_index.core.response_synthesizers import ResponseMode
import chromadb
import os
import shutil

from dotenv import load_dotenv
load_dotenv()

import nest_asyncio
nest_asyncio.apply()

# %%
dataset_source_dir = "./data/paul_graham/source_files"
dataset_config_dir = "./data/paul_graham/dataset"
index_dir = "./data/paul_graham/index"
dataset_name = "PaulGrahamEssayDataset"
eval_dir = "./data/paul_graham/eval"

similarity_top_k = 2
chunk_size = 512
chunk_overlap = 50
embedding_type = 'openai'  # https://docs.llamaindex.ai/en/stable/module_guides/models/embeddings/#list-of-supported-embeddings
response_mode = 'compact'  # https://docs.llamaindex.ai/en/stable/module_guides/querying/response_synthesizers/

# dataset generation params
num_questions_per_chunk = 1
llm = 'gpt-4'

# %%
def process_nodes(nodes,
                  chunk_size: int,
                  chunk_overlap: int,
                  embedding_type: str=None):

    transformations=[
            SentenceSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap),
        ]
    if embedding_type in [None, 'openai']:
        transformations.append(OpenAIEmbedding())  

    # https://docs.llamaindex.ai/en/stable/module_guides/loading/ingestion_pipeline/
    pipeline = IngestionPipeline(
        transformations=transformations  
    )
    nodes = pipeline.run(documents=documents)
    
    return nodes


def make_query_engine(index,
                      similarity_top_k: int=2,
                      response_mode: str='compact'):

    # configure retriever
    retriever = VectorIndexRetriever(
        index=index,
        similarity_top_k=similarity_top_k,
    )
    # configure response synthesizer
    response_synthesizer = get_response_synthesizer(
        response_mode=response_mode
    )
    # assemble query engine
    query_engine = RetrieverQueryEngine(
        retriever=retriever,
        response_synthesizer=response_synthesizer,
    )

    return query_engine

# %%
# set context for llm provider
llm_context = ServiceContext.from_defaults(
    llm=OpenAI(model=llm, temperature=0.2)
)

index_dir_ = os.path.join(index_dir, f'index_cs_{chunk_size}_co_{chunk_overlap}_em_{embedding_type}')

nodes = None
if not os.path.exists(index_dir_) or not os.listdir(index_dir_):  # create and save index if not exist
    documents = SimpleDirectoryReader(dataset_source_dir_).load_data()
    nodes = process_nodes(documents, chunk_size, chunk_overlap, embedding_type)
    # https://docs.llamaindex.ai/en/stable/module_guides/indexing/vector_store_guide/
    index = VectorStoreIndex(nodes)
    index.storage_context.persist(persist_dir=index_dir_)
else:  # load index if already exists
    # https://docs.llamaindex.ai/en/stable/understanding/storing/storing/
    storage_context = StorageContext.from_defaults(persist_dir=index_dir_)
    index = load_index_from_storage(storage_context)
    
query_engine = make_query_engine(index, similarity_top_k, response_mode)
# Out:
# /var/folders/_3/82nb1p1n24xcwn459tvc3kp40000gn/T/ipykernel_79333/313767145.py:2: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   llm_context = ServiceContext.from_defaults(

# %%
dataset_config_dir_ = os.path.join(dataset_config_dir, f'rag_dataset_cs_{chunk_size}_co_{chunk_overlap}.json')

if not os.path.exists(dataset_config_dir_):  # create and save dataset if not exist
    assert nodes is not None
    dataset_generator = RagDatasetGenerator.from_documents(
        nodes,
        service_context=llm_context,
        num_questions_per_chunk=num_questions_per_chunk,
        show_progress=True,
    )
    # this operarion may take a while
    rag_dataset = dataset_generator.generate_dataset_from_nodes()
    rag_dataset.save_json(dataset_config_dir_)
else: # load dataset if already exists
    rag_dataset = LabelledRagDataset.from_json(dataset_config_dir_)
rag_dataset.to_pandas()
# Out:
# ./data/paul_graham/dataset/rag_dataset_cs_512_co_50.json
#                                                 query  \
# 0   In the context, the author describes his early...
# 1   Discuss the transition from time-sharing machi...
# 2   In the context, the author mentions a novel an...
# 3   Based on the author's experience and observati...
# 4   In the context, the author discusses his journ...
# 5   In the provided text, the author discusses his...
# 6   What was the author's initial topic of dissert...
# 7   In the text, the author describes a unique arr...
# 8   In the provided passage, the author discusses ...
# 9   Discuss the author's experience at Interleaf, ...
# 10  Based on Paul Graham's experiences at Interlea...
# 11  In the provided text, the author compares a si...
# 12  Discuss the significance of the author's decis...
# 13  In the context, the author discusses his early...
# 14  Describe the initial challenges faced by the c...
# 15  Discuss the role of high production values in ...
# 16  In the context of the software development for...
# 17  According to the text, what did the author lea...
# 18  Based on the passage, discuss the challenges f...
# 19  Analyze the author's transition from working i...
# 20  In the context, the author discusses an idea h...
# 21  What was the initial reaction of the author to...
# 22  Discuss the impact of the internet on publishi...
# 23  According to the text, what implications did t...
# 24  Discuss the various activities and experiences...
# 25  In the context of the text, discuss how the au...
# 26  Explain the unique aspects of Y Combinator's a...
# 27  In the text, the author describes the creation...
# 28  Discuss the advantages of funding startups in ...
# 29  In the context of the text, discuss the challe...
# 30  What event in 2012 led the author to reconside...
# 31  Discuss the transition of leadership at Y Comb...
# 32  Discuss the transition in Paul Graham's career...
# 33  Explain the process and challenges faced by th...
# 34  Describe the challenges Paul Graham faced whil...
# 35  In the context document, the author discusses ...
# 36  Analyze the impact of Moore's Law on companies...
# 37  What is the significance of the name change fr...
# 38  In paragraph [19], the author discusses the co...
# 39  According to Paul Graham, what is likely to ex...
#
#                                    reference_contexts  \
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1   [On a machine without time-sharing, this was a...
# 2   [I couldn't have put this into words when I wa...
# 3   [I had gotten into a program at Cornell that d...
# 4   [So I decided to focus on Lisp. In fact, I dec...
# 5   [There, right on the wall, was something you c...
# 6   [Then one day in April 1990 a crack appeared i...
# 7   [I had some money saved from consulting work I...
# 8   [[3]\n\nWhile I was a student at the Accademia...
# 9   [This is not the only way to paint. I'm not 10...
# 10  [The good part was that I got paid huge amount...
# 11  [The foundation had merely been intro stuff, a...
# 12  [I hung around Providence for a bit, and then ...
# 13  [One day in late 1994 as I was stretching one ...
# 14  [At first this was going to be normal desktop ...
# 15  [In return for that and doing the initial lega...
# 16  [But Rtm was right, as usual. Trevor turned ou...
# 17  [We had no idea what businesses paid for thing...
# 18  [But in the long term the growth rate takes ca...
# 19  [After a few months it felt disconcertingly li...
# 20  [Part of the problem was that I didn't know ma...
# 21  [[9] You could run all sorts of services on th...
# 22  [I'd only started Viaweb because I needed the ...
# 23  [Now anyone could publish anything.\n\nThis ha...
# 24  [But when you find yourself drawn to some kind...
# 25  [In early 2005 she interviewed for a marketing...
# 26  [I'd fund it, and Jessica could quit her job a...
# 27  [That part we discovered by accident, not mere...
# 28  [I don't think it was entirely luck that the f...
# 29  [In the summer of 2006, Robert and I started w...
# 30  [If you were trying to learn the most you coul...
# 31  [And it wasn't, so I would.\n\nIn the summer o...
# 32  [What should I do next? Rtm's advice hadn't in...
# 33  [The Lisp that John McCarthy invented, or more...
# 34  [By means of an egregious collection of hacks ...
# 35  [In the fall of 2019, Bel was finally finished...
# 36  [[5] Interleaf was one of many companies that ...
# 37  [[11] People put plenty of stuff on the intern...
# 38  [But after Heroku got bought we had enough mon...
# 39  [Presumably aliens need numbers and errors and...
#
#                                      reference_answer reference_answer_by  \
# 0   The author's early experiences with programmin...          ai (gpt-4)
# 1   The text describes a transition from time-shar...          ai (gpt-4)
# 2   The novel mentioned by the author is "The Moon...          ai (gpt-4)
# 3   The author considered the approach to Artifici...          ai (gpt-4)
# 4   The author initially focused on Lisp, a progra...          ai (gpt-4)
# 5   The author attempts to balance his interests i...          ai (gpt-4)
# 6   The author initially chose "applications of co...          ai (gpt-4)
# 7   The author describes an arrangement between th...          ai (gpt-4)
# 8   The author perceives a significant difference ...          ai (gpt-4)
# 9   The author's experience at Interleaf was his c...          ai (gpt-4)
# 10  Based on Paul Graham's experiences at Interlea...          ai (gpt-4)
# 11  In the text, the author compares a signature s...          ai (gpt-4)
# 12  The author's decision to move to New York was ...          ai (gpt-4)
# 13  The author initially had the idea to start a b...          ai (gpt-4)
# 14  The creators of Viaweb initially faced the cha...          ai (gpt-4)
# 15  The author suggests that high production value...          ai (gpt-4)
# 16  The narrator, Robert, and Trevor each had dist...          ai (gpt-4)
# 17  The author learned that the growth rate is the...          ai (gpt-4)
# 18  The author faced several challenges during the...          ai (gpt-4)
# 19  The author's transition from the tech industry...          ai (gpt-4)
# 20  The author's idea was to create a web applicat...          ai (gpt-4)
# 21  The author was extremely excited about the ide...          ai (gpt-4)
# 22  Paul Graham describes a significant shift in t...          ai (gpt-4)
# 23  The author realized that the ability to publis...          ai (gpt-4)
# 24  The author engaged in a variety of activities ...          ai (gpt-4)
# 25  The author's experiences and observations play...          ai (gpt-4)
# 26  Y Combinator's approach to angel investing is ...          ai (gpt-4)
# 27  The author and his team established a program ...          ai (gpt-4)
# 28  The text describes several advantages of fundi...          ai (gpt-4)
# 29  The author faced significant challenges in man...          ai (gpt-4)
# 30  The text does not provide information on any e...          ai (gpt-4)
# 31  Paul Graham decided to hand over the leadershi...          ai (gpt-4)
# 32  Paul Graham transitioned from working on YC to...          ai (gpt-4)
# 33  The author's journey in developing the new Lis...          ai (gpt-4)
# 34  Paul Graham faced several challenges while wor...          ai (gpt-4)
# 35  The author mentions that he skipped the step o...          ai (gpt-4)
# 36  During the 1990s, Moore's Law, which predicts ...          ai (gpt-4)
# 37  The name change from Cambridge Seed to Y Combi...          ai (gpt-4)
# 38  The author uses the idea of an advanced alien ...          ai (gpt-4)
# 39  According to Paul Graham, it is likely that th...          ai (gpt-4)
#
#       query_by
# 0   ai (gpt-4)
# 1   ai (gpt-4)
# 2   ai (gpt-4)
# 3   ai (gpt-4)
# 4   ai (gpt-4)
# 5   ai (gpt-4)
# 6   ai (gpt-4)
# 7   ai (gpt-4)
# 8   ai (gpt-4)
# 9   ai (gpt-4)
# 10  ai (gpt-4)
# 11  ai (gpt-4)
# 12  ai (gpt-4)
# 13  ai (gpt-4)
# 14  ai (gpt-4)
# 15  ai (gpt-4)
# 16  ai (gpt-4)
# 17  ai (gpt-4)
# 18  ai (gpt-4)
# 19  ai (gpt-4)
# 20  ai (gpt-4)
# 21  ai (gpt-4)
# 22  ai (gpt-4)
# 23  ai (gpt-4)
# 24  ai (gpt-4)
# 25  ai (gpt-4)
# 26  ai (gpt-4)
# 27  ai (gpt-4)
# 28  ai (gpt-4)
# 29  ai (gpt-4)
# 30  ai (gpt-4)
# 31  ai (gpt-4)
# 32  ai (gpt-4)
# 33  ai (gpt-4)
# 34  ai (gpt-4)
# 35  ai (gpt-4)
# 36  ai (gpt-4)
# 37  ai (gpt-4)
# 38  ai (gpt-4)
# 39  ai (gpt-4)

# %%
response = query_engine.query("Who is Paul Graham.")

# %%
len(response.source_nodes)
# Out:
# 2

# %%
response.response
# Out:
# 'Paul Graham is an individual who was involved in organizing a Summer Founders Program for startups, where he funded a group of impressive individuals including reddit founders, Justin Kan, Emmett Shear, Aaron Swartz, and Sam Altman. Additionally, he worked on a project called Bel, an interpreter written in itself, which he completed in the fall of 2019.'

# %%
response.source_nodes[0].text
# Out:
# 'That part we discovered by accident, not merely implicitly but explicitly due to our ignorance about investing. We needed to get experience as investors. What better way, we thought, than to fund a whole bunch of startups at once? We knew undergrads got temporary jobs at tech companies during the summer. Why not organize a summer program where they\'d start startups instead? We wouldn\'t feel guilty for being in a sense fake investors, because they would in a similar sense be fake founders. So while we probably wouldn\'t make much money out of it, we\'d at least get to practice being investors on them, and they for their part would probably have a more interesting summer than they would working at Microsoft.\n\nWe\'d use the building I owned in Cambridge as our headquarters. We\'d all have dinner there once a week â\x80\x94 on tuesdays, since I was already cooking for the thursday diners on thursdays â\x80\x94 and after dinner we\'d bring in experts on startups to give talks.\n\nWe knew undergrads were deciding then about summer jobs, so in a matter of days we cooked up something we called the Summer Founders Program, and I posted an announcement on my site, inviting undergrads to apply. I had never imagined that writing essays would be a way to get "deal flow," as investors call it, but it turned out to be the perfect source. [15] We got 225 applications for the Summer Founders Program, and we were surprised to find that a lot of them were from people who\'d already graduated, or were about to that spring. Already this SFP thing was starting to feel more serious than we\'d intended.\n\nWe invited about 20 of the 225 groups to interview in person, and from those we picked 8 to fund. They were an impressive group. That first batch included reddit, Justin Kan and Emmett Shear, who went on to found Twitch, Aaron Swartz, who had already helped write the RSS spec and would a few years later become a martyr for open access, and Sam Altman, who would later become the second president of YC. I don\'t think it was entirely luck that the first batch was so good.'

# %%
from llama_index.packs.rag_evaluator.base import RagEvaluatorPack

rag_evaluator = RagEvaluatorPack(
    query_engine=query_engine,
    rag_dataset=rag_dataset,
)
benchmark_df = rag_evaluator.run()

# %%
benchmark_df.head()
# Out:
# rag                            base_rag
# metrics
# mean_correctness_score         3.987500
# mean_relevancy_score           0.875000
# mean_faithfulness_score        1.000000
# mean_context_similarity_score  0.961158

# %%
eval_dir_ = os.path.join(eval_dir, f'index_cs_{chunk_size}_co_{chunk_overlap}_em_{embedding_type}_k_{similarity_top_k}')
os.makedirs(eval_dir_, exist_ok=True)
shutil.move('_evaluations.json', eval_dir_)
shutil.move('benchmark.csv', eval_dir_)
# Out:
# './data/paul_graham/eval/index_cs_512_co_50_em_openai/benchmark.csv'

# %%
# test retriever

# %%
rag_evaluator.prediction_dataset.to_pandas()
# Out:
#                                              response  \
# 0   The author faced challenges with programming o...
# 1   The transition from time-sharing machines to m...
# 2   The author mentions a novel called "The Moon i...
# 3   The author considered the approach to Artifici...
# 4   The author initially focused on Lisp and syste...
# 5   The author in the text describes his interest ...
# 6   The author's initial topic of dissertation was...
# 7   The author describes an arrangement at the Acc...
# 8   The author highlights the distinction between ...
# 9   The author's experience at Interleaf provided ...
# 10  Paul Graham learned from his experiences at In...
# 11  The comparison made by the author between a si...
# 12  The author's decision to move to New York and ...
# 13  The author's initial business idea was to put ...
# 14  The creators of Viaweb initially faced challen...
# 15  The text highlights the importance of high pro...
# 16  The team working on the software development f...
# 17  The author learned that the growth rate is the...
# 18  The author faced challenges during the growth ...
# 19  The author's transition from working in the te...
# 20  The author discusses an idea in the context ab...
# 21  The author was initially very excited about th...
# 22  Paul Graham highlights the transformative impa...
# 23  The author realized that the ability to publis...
# 24  The author engaged in a variety of activities ...
# 25  The author's dissatisfaction with traditional ...
# 26  Y Combinator's approach to angel investing is ...
# 27  The author and their team decided to create a ...
# 28  Funding startups in batches offers several adv...
# 29  The challenges faced by the author in managing...
# 30  In 2012, the author's mother had a stroke caus...
# 31  The transition of leadership at Y Combinator (...
# 32  Paul Graham transitioned from painting to writ...
# 33  The author embarked on developing the new Lisp...
# 34  Paul Graham faced challenges while working on ...
# 35  The author skipped studying programming in col...
# 36  Moore's Law had a significant impact on compan...
# 37  The significance of the name change from Cambr...
# 38  The author uses the example of space aliens to...
# 39  Numbers, errors, and I/O are likely to exist i...
#
#                                              contexts
# 0   [What I Worked On\n\nFebruary 2021\n\nBefore c...
# 1   [On a machine without time-sharing, this was a...
# 2   [I had gotten into a program at Cornell that d...
# 3   [I had gotten into a program at Cornell that d...
# 4   [So I decided to focus on Lisp. In fact, I dec...
# 5   [There, right on the wall, was something you c...
# 6   [Then one day in April 1990 a crack appeared i...
# 7   [I had some money saved from consulting work I...
# 8   [[3]\n\nWhile I was a student at the Accademia...
# 9   [The good part was that I got paid huge amount...
# 10  [The good part was that I got paid huge amount...
# 11  [The foundation had merely been intro stuff, a...
# 12  [Part of the problem was that I didn't know ma...
# 13  [One day in late 1994 as I was stretching one ...
# 14  [At first this was going to be normal desktop ...
# 15  [We had no idea what businesses paid for thing...
# 16  [But Rtm was right, as usual. Trevor turned ou...
# 17  [We had no idea what businesses paid for thing...
# 18  [But in the long term the growth rate takes ca...
# 19  [There, right on the wall, was something you c...
# 20  [[9] You could run all sorts of services on th...
# 21  [[9] You could run all sorts of services on th...
# 22  [I'd only started Viaweb because I needed the ...
# 23  [Now anyone could publish anything.\n\nThis ha...
# 24  [But when you find yourself drawn to some kind...
# 25  [In early 2005 she interviewed for a marketing...
# 26  [I'd fund it, and Jessica could quit her job a...
# 27  [That part we discovered by accident, not mere...
# 28  [I don't think it was entirely luck that the f...
# 29  [In the summer of 2006, Robert and I started w...
# 30  [If you were trying to learn the most you coul...
# 31  [And it wasn't, so I would.\n\nIn the summer o...
# 32  [What should I do next? Rtm's advice hadn't in...
# 33  [The Lisp that John McCarthy invented, or more...
# 34  [By means of an egregious collection of hacks ...
# 35  [On a machine without time-sharing, this was a...
# 36  [[5] Interleaf was one of many companies that ...
# 37  [[11] People put plenty of stuff on the intern...
# 38  [But after Heroku got bought we had enough mon...
# 39  [The Lisp that John McCarthy invented, or more...

# %%
from llama_index.core.evaluation import RetrieverEvaluator, RetrievalEvalResult
from llama_index.core.evaluation.retrieval.metrics import HitRate, MRR, resolve_metrics

# TODO add cohere rank
metric_names = ["mrr", "hit_rate"]
metric_types = resolve_metrics(metric_names)
metrics=[metric() for metric in metric_types]
df_rag_evaluator = rag_evaluator.prediction_dataset.to_pandas()
df_rag_dataset = rag_dataset.to_pandas()

eval_results = []
for i in range(len(df_rag_evaluator)):
    metric_dict = {}
    for metric in metrics:
        eval_result = metric.compute(
            retrieved_ids=df_rag_evaluator['contexts'].tolist()[i], expected_ids=df_rag_dataset['reference_contexts'].tolist()[i]
        )
        metric_dict[metric.metric_name] = eval_result
    eval_results.append(
        RetrievalEvalResult(metric_dict=metric_dict,
                            query=df_rag_dataset['query'].tolist()[i],
                            retrieved_texts=df_rag_evaluator['contexts'].tolist()[i],
                            retrieved_ids=df_rag_evaluator['contexts'].tolist()[i],
                            expected_ids=df_rag_dataset['reference_contexts'].tolist()[i],
                            expected_texts=df_rag_dataset['reference_contexts'].tolist()[i])
    )

# %%
metric_dicts = []
for eval_result in eval_results:
  metric_dict = eval_result.metric_vals_dict
  metric_dicts.append(metric_dict)
full_df = pd.DataFrame(metric_dicts)

mean_metrics = {"mean_hit_rate": full_df["hit_rate"].mean(),
                "mean_mrr": full_df["mrr"].mean()}
data = {
    "metrics": list(mean_metrics.keys()),
    "score": list(mean_metrics.values())
}

metric_df = pd.DataFrame(data).reset_index(drop=True)
metric_df.head()
# Out:
#          metrics  score
# 0  mean_hit_rate   0.90
# 1       mean_mrr   0.85

# %%
eval_path = os.path.join(eval_dir_, 'retrieval_benchmark.csv')
metric_df.to_csv(eval_path, index=False)
